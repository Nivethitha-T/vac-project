# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e3aa5c4b-1c54-4435-abda-3cff75cb9226" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3aa5c4b-1c54-4435-abda-3cff75cb9226">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(list(uploaded.keys())[0])
print(df.head())
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
X = df.drop("Class", axis=1)
y = df["Class"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = LogisticRegression()
model.fit(X_train_scaled, y_train)

print("Model Trained Successfully!")
# Out:
# Model Trained Successfully!

# %%
def predict_fraud(input_list):
    scaled = scaler.transform([input_list])
    pred = model.predict(scaled)[0]
    return "FRAUD" if pred == 1 else "NOT FRAUD"
    print("\nEnter transaction details to predict:")

# %%
sample = []

for col in X.columns:
    value = float(input(f"Enter value for {col}: "))
    sample.append(value)

result = predict_fraud(sample)
print("\nPrediction:", result)
# Out:
# Enter value for Time: 98
# Enter value for V1: 06
# Enter value for V2: 78
# Enter value for V3: 45
# Enter value for V4: 34
# Enter value for V5: 23
# Enter value for V6: 24
# Enter value for V7: 56
# Enter value for V8: 87
# Enter value for V9: 67
# Enter value for V10: 556
# Enter value for V11: 45
# Enter value for V12: 34
# Enter value for V13: 78
# Enter value for V14: 34
# Enter value for V15: 23
# Enter value for V16: 67
# Enter value for V17: 89
# Enter value for V18: 45
# Enter value for V19: 56
# Enter value for V20: 67
# Enter value for V21: 78
# Enter value for V22: 90
# Enter value for V23: 45
# Enter value for V24: 67
# Enter value for V25: 67
# Enter value for V26: 78
# Enter value for V27: 56
# Enter value for V28: 54
# Enter value for Amount: 34567
#
# Prediction: NOT FRAUD
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Amount'],df['Class'],color='red')
plt.title('Amount vs Class')
plt.xlabel('Amount')
plt.ylabel('Class')
plt.show()

# %%
plt.subplot(2,2,1)
plt.scatter(df['Time'],df['Class'],color='red')
plt.title('Time vs Class')
plt.xlabel('Time')
plt.ylabel('Class')
plt.xticks(rotation=45,ha='right')
plt.subplot(2,2,2)
plt.bar(df['Time'],df['Class'],color='red')
plt.xlabel('City')
plt.ylabel('Time')
plt.title('Bar plot')
plt.subplot(2,2,3)
plt.scatter(df['City'],df['Time'],color='red')
plt.title('Scatter plot')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-972353608.py in <cell line: 0>()
# ----> 1 plt.pie(df['Class'],labels=df['Amount'])
#       2 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3795     data=None,
# ...
